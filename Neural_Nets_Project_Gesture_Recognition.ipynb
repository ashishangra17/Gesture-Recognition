# %% [markdown]
# # Gesture Recognition
# In this group project, you are going to build a 3D Conv model that will be able to predict the 5 gestures correctly. Please import the following libraries to get started.

# %%
import numpy as np
import os
from scipy.misc import imread, imresize
import datetime
import os

# %% [markdown]
# We set the random seed so that the results don't vary drastically.

# %%
np.random.seed(30)
import random as rn
rn.seed(30)
from keras import backend as K
import tensorflow as tf
tf.set_random_seed(30)
# Out:
# Using TensorFlow backend.

# %%
import cv2
import matplotlib.pyplot as plt
% matplotlib inline

# %%
from keras.models import Sequential, Model
from keras.layers import Dense, GRU, Flatten, TimeDistributed, Flatten, BatchNormalization, Activation
from keras.layers.convolutional import Conv3D, MaxPooling3D, Conv2D, MaxPooling2D
from keras.layers.recurrent import LSTM
from keras.callbacks import ModelCheckpoint, ReduceLROnPlateau
from keras import optimizers
from keras.layers import Dropout

# %% [markdown]
# In this block, you read the folder names for training and validation. You also set the `batch_size` here. Note that you set the batch size in such a way that you are able to use the GPU in full capacity. You keep increasing the batch size until the machine throws an error.

# %%
train_doc = np.random.permutation(open('Project_data/train.csv').readlines())
val_doc = np.random.permutation(open('Project_data/val.csv').readlines())
project_folder='Project_data'

# %% [markdown]
# ## Generator
# This is one of the most important part of the code. The overall structure of the generator has been given. In the generator, you are going to preprocess the images as you have images of 2 different dimensions as well as create a batch of video frames. You have to experiment with `img_idx`, `y`,`z` and normalization such that you get high accuracy.

# %%
class ModelBuilder():
    
    def initialize_path(self,project_folder):
        self.train_doc = np.random.permutation(open(project_folder + '/' + 'train.csv').readlines())
        self.val_doc = np.random.permutation(open(project_folder + '/' + 'val.csv').readlines())
        self.train_path = project_folder + '/' + 'train'
        self.val_path =  project_folder + '/' + 'val'
        self.num_train_sequences = len(self.train_doc)
        self.num_val_sequences = len(self.val_doc)
        
    def initialize_image_properties(self,image_height=100,image_width=100):
        self.image_height=image_height
        self.image_width=image_width
        self.channels=3
        self.num_classes=5
        self.total_frames=30
          
    def initialize_hyperparams(self,frames_to_sample=30,batch_size=20,num_epochs=20):
        self.frames_to_sample=frames_to_sample
        self.batch_size=batch_size
        self.num_epochs=num_epochs
        
        
    def generator(self,source_path, folder_list, augment=False):
        img_idx = np.round(np.linspace(0,self.total_frames-1,self.frames_to_sample)).astype(int)
        batch_size=self.batch_size
        while True:
            t = np.random.permutation(folder_list)
            num_batches = len(t)//batch_size
        
            for batch in range(num_batches): 
                batch_data, batch_labels= self.one_batch_data(source_path,t,batch,batch_size,img_idx,augment)
                yield batch_data, batch_labels 

            remaining_seq=len(t)%batch_size
        
            if (remaining_seq != 0):
                batch_data, batch_labels= self.one_batch_data(source_path,t,num_batches,batch_size,img_idx,augment,remaining_seq)
                yield batch_data, batch_labels 
    
    
    def one_batch_data(self,source_path,t,batch,batch_size,img_idx,augment,remaining_seq=0):
    
        seq_len = remaining_seq if remaining_seq else batch_size
    
        batch_data = np.zeros((seq_len,len(img_idx),self.image_height,self.image_width,self.channels)) 
        batch_labels = np.zeros((seq_len,self.num_classes)) 
    
        if (augment): batch_data_aug = np.zeros((seq_len,len(img_idx),self.image_height,self.image_width,self.channels))

        
        for folder in range(seq_len): 
            imgs = os.listdir(source_path+'/'+ t[folder + (batch*batch_size)].split(';')[0]) 
            for idx,item in enumerate(img_idx): 
                image = imread(source_path+'/'+ t[folder + (batch*batch_size)].strip().split(';')[0]+'/'+imgs[item]).astype(np.float32)
                image_resized=imresize(image,(self.image_height,self.image_width,3))
            

                batch_data[folder,idx,:,:,0] = (image_resized[:,:,0])/255
                batch_data[folder,idx,:,:,1] = (image_resized[:,:,1])/255
                batch_data[folder,idx,:,:,2] = (image_resized[:,:,2])/255
            
                if (augment):
                    shifted = cv2.warpAffine(image, 
                                             np.float32([[1, 0, np.random.randint(-30,30)],[0, 1, np.random.randint(-30,30)]]), 
                                            (image.shape[1], image.shape[0]))
                    
                    gray = cv2.cvtColor(shifted,cv2.COLOR_BGR2GRAY)

                    x0, y0 = np.argwhere(gray > 0).min(axis=0)
                    x1, y1 = np.argwhere(gray > 0).max(axis=0) 
                    
                    cropped=shifted[x0:x1,y0:y1,:]
                    
                    image_resized=imresize(cropped,(self.image_height,self.image_width,3))
                    
                         
                    batch_data_aug[folder,idx,:,:,0] = (image_resized[:,:,0])/255
                    batch_data_aug[folder,idx,:,:,1] = (image_resized[:,:,1])/255
                    batch_data_aug[folder,idx,:,:,2] = (image_resized[:,:,2])/255
                
            
            batch_labels[folder, int(t[folder + (batch*batch_size)].strip().split(';')[2])] = 1
            
    
        if (augment):
            batch_data=np.concatenate([batch_data,batch_data_aug])
            batch_labels=np.concatenate([batch_labels,batch_labels])

        
        return(batch_data,batch_labels)
    
    
    def train_model(self, model, augment_data=False):
        train_generator = self.generator(self.train_path, self.train_doc,augment=augment_data)
        val_generator = self.generator(self.val_path, self.val_doc)

        model_name = 'model_init' + '_' + str(datetime.datetime.now()).replace(' ','').replace(':','_') + '/'
    
        if not os.path.exists(model_name):
            os.mkdir(model_name)
        
        filepath = model_name + 'model-{epoch:05d}-{loss:.5f}-{categorical_accuracy:.5f}-{val_loss:.5f}-{val_categorical_accuracy:.5f}.h5'

        checkpoint = ModelCheckpoint(filepath, monitor='val_loss', verbose=1, save_best_only=False, save_weights_only=False, mode='auto', period=1)
        LR = ReduceLROnPlateau(monitor='val_loss', factor=0.2, verbose=1, patience=4)
        callbacks_list = [checkpoint, LR]

        if (self.num_train_sequences%self.batch_size) == 0:
            steps_per_epoch = int(self.num_train_sequences/self.batch_size)
        else:
            steps_per_epoch = (self.num_train_sequences//self.batch_size) + 1

        if (self.num_val_sequences%self.batch_size) == 0:
            validation_steps = int(self.num_val_sequences/self.batch_size)
        else:
            validation_steps = (self.num_val_sequences//self.batch_size) + 1
    
        history=model.fit_generator(train_generator, steps_per_epoch=steps_per_epoch, epochs=self.num_epochs, verbose=1, 
                            callbacks=callbacks_list, validation_data=val_generator, 
                            validation_steps=validation_steps, class_weight=None, workers=1, initial_epoch=0)
        return history

# %% [markdown]
# ### Define a function for Plotting

# %%
def plot(history):
    fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(15,4))
    axes[0].plot(history.history['loss'])   
    axes[0].plot(history.history['val_loss'])
    axes[0].legend(['loss','val_loss'])

    axes[1].plot(history.history['categorical_accuracy'])   
    axes[1].plot(history.history['val_categorical_accuracy'])
    axes[1].legend(['categorical_accuracy','val_categorical_accuracy'])

# %% [markdown]
# ## Conv 3D : Model 1
# Image : 160 * 160, Frames : 30 , Epochs : 1, Batch Size : 40

# %%
class ModelConv3D1(ModelBuilder):
    
    def define_model(self):

        model = Sequential()
        model.add(Conv3D(16, (3, 3, 3), padding='same',
                 input_shape=(self.frames_to_sample,self.image_height,self.image_width,self.channels)))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        model.add(MaxPooling3D(pool_size=(2, 2, 2)))

        model.add(Conv3D(32, (2, 2, 2), padding='same'))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        model.add(MaxPooling3D(pool_size=(2, 2, 2)))

        model.add(Conv3D(64, (2, 2, 2), padding='same'))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        model.add(MaxPooling3D(pool_size=(2, 2, 2)))

        model.add(Conv3D(128, (2, 2, 2), padding='same'))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        model.add(MaxPooling3D(pool_size=(2, 2, 2)))

        model.add(Flatten())
        model.add(Dense(128,activation='relu'))
        model.add(BatchNormalization())
        model.add(Dropout(0.5))

        model.add(Dense(64,activation='relu'))
        model.add(BatchNormalization())
        model.add(Dropout(0.25))


        model.add(Dense(self.num_classes,activation='softmax'))

        optimiser = optimizers.Adam()
        model.compile(optimizer=optimiser, loss='categorical_crossentropy', metrics=['categorical_accuracy'])
        return model

# %%
conv_3d1=ModelConv3D1()
conv_3d1.initialize_path(project_folder)
conv_3d1.initialize_image_properties(image_height=160,image_width=160)
conv_3d1.initialize_hyperparams(frames_to_sample=30,batch_size=40,num_epochs=1)
conv_3d1_model=conv_3d1.define_model()
print("Total Params:", conv_3d1_model.count_params())
conv_3d1_model.summary()
model1 = conv_3d1.train_model(conv_3d1_model)
# Out:
# Total Params: 1736389
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv3d_1 (Conv3D)            (None, 30, 160, 160, 16)  1312
# _________________________________________________________________
# activation_1 (Activation)    (None, 30, 160, 160, 16)  0
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 30, 160, 160, 16)  64
# _________________________________________________________________
# max_pooling3d_1 (MaxPooling3 (None, 15, 80, 80, 16)    0
# _________________________________________________________________
# conv3d_2 (Conv3D)            (None, 15, 80, 80, 32)    4128
# _________________________________________________________________
# activation_2 (Activation)    (None, 15, 80, 80, 32)    0
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 15, 80, 80, 32)    128
# _________________________________________________________________
# max_pooling3d_2 (MaxPooling3 (None, 7, 40, 40, 32)     0
# _________________________________________________________________
# conv3d_3 (Conv3D)            (None, 7, 40, 40, 64)     16448
# _________________________________________________________________
# activation_3 (Activation)    (None, 7, 40, 40, 64)     0
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 7, 40, 40, 64)     256
# _________________________________________________________________
# max_pooling3d_3 (MaxPooling3 (None, 3, 20, 20, 64)     0
# _________________________________________________________________
# conv3d_4 (Conv3D)            (None, 3, 20, 20, 128)    65664
# _________________________________________________________________
# activation_4 (Activation)    (None, 3, 20, 20, 128)    0
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 3, 20, 20, 128)    512
# _________________________________________________________________
# max_pooling3d_4 (MaxPooling3 (None, 1, 10, 10, 128)    0
# _________________________________________________________________
# flatten_1 (Flatten)          (None, 12800)             0
# _________________________________________________________________
# dense_1 (Dense)              (None, 128)               1638528
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 128)               512
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 64)                8256
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 64)                256
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_3 (Dense)              (None, 5)                 325
# =================================================================
# Total params: 1,736,389
# Trainable params: 1,735,525
# Non-trainable params: 864
# _________________________________________________________________
# Epoch 1/1
# /mnt/disks/user/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:55: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imread`` instead.
# /mnt/disks/user/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:56: DeprecationWarning: `imresize` is deprecated!
# `imresize` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``skimage.transform.resize`` instead.
# ---------------------------------------------------------------------------
# ResourceExhaustedError                    Traceback (most recent call last)
# <ipython-input-13-a559d61e4d7c> in <module>()
#       6 print("Total Params:", conv_3d1_model.count_params())
#       7 conv_3d1_model.summary()
# ----> 8 model1 = conv_3d1.train_model(conv_3d1_model)
#
# <ipython-input-10-568862929842> in train_model(self, model, augment_data)
#     122         history=model.fit_generator(train_generator, steps_per_epoch=steps_per_epoch, epochs=self.num_epochs, verbose=1,
#     123                             callbacks=callbacks_list, validation_data=val_generator,
# --> 124                             validation_steps=validation_steps, class_weight=None, workers=1, initial_epoch=0)
#     125         return history
#
# /mnt/disks/user/anaconda3/lib/python3.6/site-packages/keras/legacy/interfaces.py in wrapper(*args, **kwargs)
#      89                 warnings.warn('Update your `' + object_name +
#      90                               '` call to the Keras 2 API: ' + signature, stacklevel=2)
# ---> 91             return func(*args, **kwargs)
#      92         wrapper._original_function = func
#      93         return wrapper
#
# /mnt/disks/user/anaconda3/lib/python3.6/site-packages/keras/engine/training.py in fit_generator(self, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch)
#    1413             use_multiprocessing=use_multiprocessing,
#    1414             shuffle=shuffle,
# -> 1415             initial_epoch=initial_epoch)
#    1416
#    1417     @interfaces.legacy_generator_methods_support
#
# /mnt/disks/user/anaconda3/lib/python3.6/site-packages/keras/engine/training_generator.py in fit_generator(model, generator, steps_per_epoch, epochs, verbose, callbacks, validation_data, validation_steps, class_weight, max_queue_size, workers, use_multiprocessing, shuffle, initial_epoch)
#     211                 outs = model.train_on_batch(x, y,
#     212                                             sample_weight=sample_weight,
# --> 213                                             class_weight=class_weight)
#     214
#     215                 outs = to_list(outs)
#
# /mnt/disks/user/anaconda3/lib/python3.6/site-packages/keras/engine/training.py in train_on_batch(self, x, y, sample_weight, class_weight)
#    1213             ins = x + y + sample_weights
#    1214         self._make_train_function()
# -> 1215         outputs = self.train_function(ins)
#    1216         return unpack_singleton(outputs)
#    1217
#
# /mnt/disks/user/anaconda3/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py in __call__(self, inputs)
#    2664                 return self._legacy_call(inputs)
#    2665
# -> 2666             return self._call(inputs)
#    2667         else:
#    2668             if py_any(is_tensor(x) for x in inputs):
#
# /mnt/disks/user/anaconda3/lib/python3.6/site-packages/keras/backend/tensorflow_backend.py in _call(self, inputs)
#    2634                                 symbol_vals,
#    2635                                 session)
# -> 2636         fetched = self._callable_fn(*array_vals)
#    2637         return fetched[:len(self.outputs)]
#    2638
#
# /mnt/disks/user/anaconda3/lib/python3.6/site-packages/tensorflow/python/client/session.py in __call__(self, *args, **kwargs)
#    1380           ret = tf_session.TF_SessionRunCallable(
#    1381               self._session._session, self._handle, args, status,
# -> 1382               run_metadata_ptr)
#    1383         if run_metadata:
#    1384           proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# /mnt/disks/user/anaconda3/lib/python3.6/site-packages/tensorflow/python/framework/errors_impl.py in __exit__(self, type_arg, value_arg, traceback_arg)
#     517             None, None,
#     518             compat.as_text(c_api.TF_Message(self.status.status)),
# --> 519             c_api.TF_GetCode(self.status.status))
#     520     # Delete the underlying status object from memory otherwise it stays alive
#     521     # as there is a reference to status from this from the traceback due to
#
# ResourceExhaustedError: OOM when allocating tensor with shape[40,16,30,160,160] and type float on /job:localhost/replica:0/task:0/device:GPU:0 by allocator GPU_0_bfc
# 	 [[Node: training/Adam/gradients/max_pooling3d_1/MaxPool3D_grad/MaxPool3DGrad = MaxPool3DGrad[T=DT_FLOAT, TInput=DT_FLOAT, _class=["loc:@training/Adam/gradients/batch_normalization_1/cond/Merge_grad/cond_grad"], data_format="NDHWC", ksize=[1, 2, 2, 2, 1], padding="VALID", strides=[1, 2, 2, 2, 1], _device="/job:localhost/replica:0/task:0/device:GPU:0"](batch_normalization_1/cond/Merge, max_pooling3d_1/MaxPool3D, training/Adam/gradients/conv3d_2/convolution_grad/Conv3DBackpropInputV2)]]
# Hint: If you want to see a list of allocated tensors when OOM happens, add report_tensor_allocations_upon_oom to RunOptions for current allocation info.

# %% [markdown]
# ### The Model throws Out of Memory, when the batch size is 40 and epoch is 1.
# In Next Model, batch size can be reduced.

# %% [markdown]
# Note here that a video is represented above in the generator as (number of images, height, width, number of channels). Take this into consideration while creating the model architecture.

# %% [markdown]
# Now that you have written the model, the next step is to `compile` the model. When you print the `summary` of the model, you'll see the total number of parameters you have to train.

# %% [markdown]
# ### Conv 3D Model 2 (Architecture same as Model1 with change in HyperParameters)
# Image : 160 * 160, Frames : 30 , Epochs : 1, Batch Size : 30

# %%
conv_3d2=ModelConv3D1()
conv_3d2.initialize_path(project_folder)
conv_3d2.initialize_image_properties(image_height=160,image_width=160)
conv_3d2.initialize_hyperparams(frames_to_sample=30,batch_size=30,num_epochs=1)
conv_3d2_model=conv_3d2.define_model()
conv_3d2_model.summary()
print("Total Params:", conv_3d2_model.count_params())
history_model2 = conv_3d2.train_model(conv_3d2_model)
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv3d_5 (Conv3D)            (None, 30, 160, 160, 16)  1312
# _________________________________________________________________
# activation_5 (Activation)    (None, 30, 160, 160, 16)  0
# _________________________________________________________________
# batch_normalization_7 (Batch (None, 30, 160, 160, 16)  64
# _________________________________________________________________
# max_pooling3d_5 (MaxPooling3 (None, 15, 80, 80, 16)    0
# _________________________________________________________________
# conv3d_6 (Conv3D)            (None, 15, 80, 80, 32)    4128
# _________________________________________________________________
# activation_6 (Activation)    (None, 15, 80, 80, 32)    0
# _________________________________________________________________
# batch_normalization_8 (Batch (None, 15, 80, 80, 32)    128
# _________________________________________________________________
# max_pooling3d_6 (MaxPooling3 (None, 7, 40, 40, 32)     0
# _________________________________________________________________
# conv3d_7 (Conv3D)            (None, 7, 40, 40, 64)     16448
# _________________________________________________________________
# activation_7 (Activation)    (None, 7, 40, 40, 64)     0
# _________________________________________________________________
# batch_normalization_9 (Batch (None, 7, 40, 40, 64)     256
# _________________________________________________________________
# max_pooling3d_7 (MaxPooling3 (None, 3, 20, 20, 64)     0
# _________________________________________________________________
# conv3d_8 (Conv3D)            (None, 3, 20, 20, 128)    65664
# _________________________________________________________________
# activation_8 (Activation)    (None, 3, 20, 20, 128)    0
# _________________________________________________________________
# batch_normalization_10 (Batc (None, 3, 20, 20, 128)    512
# _________________________________________________________________
# max_pooling3d_8 (MaxPooling3 (None, 1, 10, 10, 128)    0
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 12800)             0
# _________________________________________________________________
# dense_4 (Dense)              (None, 128)               1638528
# _________________________________________________________________
# batch_normalization_11 (Batc (None, 128)               512
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_5 (Dense)              (None, 64)                8256
# _________________________________________________________________
# batch_normalization_12 (Batc (None, 64)                256
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_6 (Dense)              (None, 5)                 325
# =================================================================
# Total params: 1,736,389
# Trainable params: 1,735,525
# Non-trainable params: 864
# _________________________________________________________________
# Total Params: 1736389
# Epoch 1/1
# /mnt/disks/user/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:55: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imread`` instead.
# /mnt/disks/user/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:56: DeprecationWarning: `imresize` is deprecated!
# `imresize` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``skimage.transform.resize`` instead.
# 23/23 [==============================] - 168s 7s/step - loss: 1.5901 - categorical_accuracy: 0.3894 - val_loss: 1.2286 - val_categorical_accuracy: 0.5400
#
# Epoch 00001: saving model to model_init_2021-02-0807_13_19.506464/model-00001-1.59621-0.37858-1.22860-0.54000.h5

# %% [markdown]
# ### Conclusion :
# Train and Validation Accuracy is very low i.e. 38% and 54% respectively.

# %% [markdown]
# ### Model 3 (Architecture same as Model1 with change in HyperParameters)
# Image : 160 * 160, Frames : 30 , Epochs : 10, Batch Size : 30

# %%
conv_3d3=ModelConv3D1()
conv_3d3.initialize_path(project_folder)
conv_3d3.initialize_image_properties(image_height=160,image_width=160)
conv_3d3.initialize_hyperparams(frames_to_sample=30,batch_size=30,num_epochs=10)
conv_3d3_model=conv_3d3.define_model()
conv_3d3_model.summary()
print("Total Params:", conv_3d3_model.count_params())
history_model3 = conv_3d3.train_model(conv_3d3_model)
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv3d_9 (Conv3D)            (None, 30, 160, 160, 16)  1312
# _________________________________________________________________
# activation_9 (Activation)    (None, 30, 160, 160, 16)  0
# _________________________________________________________________
# batch_normalization_13 (Batc (None, 30, 160, 160, 16)  64
# _________________________________________________________________
# max_pooling3d_9 (MaxPooling3 (None, 15, 80, 80, 16)    0
# _________________________________________________________________
# conv3d_10 (Conv3D)           (None, 15, 80, 80, 32)    4128
# _________________________________________________________________
# activation_10 (Activation)   (None, 15, 80, 80, 32)    0
# _________________________________________________________________
# batch_normalization_14 (Batc (None, 15, 80, 80, 32)    128
# _________________________________________________________________
# max_pooling3d_10 (MaxPooling (None, 7, 40, 40, 32)     0
# _________________________________________________________________
# conv3d_11 (Conv3D)           (None, 7, 40, 40, 64)     16448
# _________________________________________________________________
# activation_11 (Activation)   (None, 7, 40, 40, 64)     0
# _________________________________________________________________
# batch_normalization_15 (Batc (None, 7, 40, 40, 64)     256
# _________________________________________________________________
# max_pooling3d_11 (MaxPooling (None, 3, 20, 20, 64)     0
# _________________________________________________________________
# conv3d_12 (Conv3D)           (None, 3, 20, 20, 128)    65664
# _________________________________________________________________
# activation_12 (Activation)   (None, 3, 20, 20, 128)    0
# _________________________________________________________________
# batch_normalization_16 (Batc (None, 3, 20, 20, 128)    512
# _________________________________________________________________
# max_pooling3d_12 (MaxPooling (None, 1, 10, 10, 128)    0
# _________________________________________________________________
# flatten_3 (Flatten)          (None, 12800)             0
# _________________________________________________________________
# dense_7 (Dense)              (None, 128)               1638528
# _________________________________________________________________
# batch_normalization_17 (Batc (None, 128)               512
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_8 (Dense)              (None, 64)                8256
# _________________________________________________________________
# batch_normalization_18 (Batc (None, 64)                256
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_9 (Dense)              (None, 5)                 325
# =================================================================
# Total params: 1,736,389
# Trainable params: 1,735,525
# Non-trainable params: 864
# _________________________________________________________________
# Total Params: 1736389
# Epoch 1/10
# /mnt/disks/user/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:55: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imread`` instead.
# /mnt/disks/user/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:56: DeprecationWarning: `imresize` is deprecated!
# `imresize` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``skimage.transform.resize`` instead.
# 23/23 [==============================] - 100s 4s/step - loss: 1.4850 - categorical_accuracy: 0.4402 - val_loss: 1.2746 - val_categorical_accuracy: 0.5700
#
# Epoch 00001: saving model to model_init_2021-02-0807_22_27.046052/model-00001-1.51240-0.43137-1.27456-0.57000.h5
# Epoch 2/10
# 23/23 [==============================] - 86s 4s/step - loss: 1.0480 - categorical_accuracy: 0.5874 - val_loss: 1.1201 - val_categorical_accuracy: 0.5200
#
# Epoch 00002: saving model to model_init_2021-02-0807_22_27.046052/model-00002-1.01897-0.59729-1.12014-0.52000.h5
# Epoch 3/10
# 23/23 [==============================] - 88s 4s/step - loss: 0.8320 - categorical_accuracy: 0.6609 - val_loss: 0.7990 - val_categorical_accuracy: 0.6600
#
# Epoch 00003: saving model to model_init_2021-02-0807_22_27.046052/model-00003-0.84227-0.66063-0.79899-0.66000.h5
# Epoch 4/10
# 23/23 [==============================] - 89s 4s/step - loss: 0.8334 - categorical_accuracy: 0.6556 - val_loss: 1.2093 - val_categorical_accuracy: 0.5400
#
# Epoch 00004: saving model to model_init_2021-02-0807_22_27.046052/model-00004-0.82853-0.66817-1.20928-0.54000.h5
# Epoch 5/10
# 23/23 [==============================] - 88s 4s/step - loss: 0.8092 - categorical_accuracy: 0.7050 - val_loss: 1.1134 - val_categorical_accuracy: 0.6200
#
# Epoch 00005: saving model to model_init_2021-02-0807_22_27.046052/model-00005-0.76226-0.71946-1.11340-0.62000.h5
# Epoch 6/10
# 23/23 [==============================] - 87s 4s/step - loss: 0.6099 - categorical_accuracy: 0.7808 - val_loss: 1.0250 - val_categorical_accuracy: 0.6800
#
# Epoch 00006: saving model to model_init_2021-02-0807_22_27.046052/model-00006-0.61711-0.77225-1.02496-0.68000.h5
# Epoch 7/10
# 23/23 [==============================] - 86s 4s/step - loss: 0.5514 - categorical_accuracy: 0.7805 - val_loss: 0.9329 - val_categorical_accuracy: 0.6800
#
# Epoch 00007: saving model to model_init_2021-02-0807_22_27.046052/model-00007-0.53561-0.79789-0.93291-0.68000.h5
#
# Epoch 00007: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# Epoch 8/10
# 23/23 [==============================] - 88s 4s/step - loss: 0.4927 - categorical_accuracy: 0.8008 - val_loss: 0.9349 - val_categorical_accuracy: 0.6900
#
# Epoch 00008: saving model to model_init_2021-02-0807_22_27.046052/model-00008-0.47007-0.81900-0.93495-0.69000.h5
# Epoch 9/10
# 23/23 [==============================] - 86s 4s/step - loss: 0.4447 - categorical_accuracy: 0.8606 - val_loss: 0.6674 - val_categorical_accuracy: 0.7800
#
# Epoch 00009: saving model to model_init_2021-02-0807_22_27.046052/model-00009-0.44335-0.85520-0.66739-0.78000.h5
# Epoch 10/10
# 23/23 [==============================] - 85s 4s/step - loss: 0.4123 - categorical_accuracy: 0.8380 - val_loss: 0.7985 - val_categorical_accuracy: 0.7400
#
# Epoch 00010: saving model to model_init_2021-02-0807_22_27.046052/model-00010-0.41217-0.84465-0.79850-0.74000.h5

# %% [markdown]
# ### Conclusion : The accuracy increased to 83/80 % with number of epochs but execution time also increases.

# %% [markdown]
# ### Model 4 (Architecture same as Model1 with change in HyperParameters)
# Image : 160 * 160, Frames : 30 , Epochs : 30, Batch Size : 30

# %%
conv_3d4=ModelConv3D1()
conv_3d4.initialize_path(project_folder)
conv_3d4.initialize_image_properties(image_height=160,image_width=160)
conv_3d4.initialize_hyperparams(frames_to_sample=30,batch_size=30,num_epochs=30)
conv_3d4_model=conv_3d4.define_model()
conv_3d4_model.summary()
print("Total Params:", conv_3d4_model.count_params())
history_model4 = conv_3d4.train_model(conv_3d4_model)
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv3d_13 (Conv3D)           (None, 30, 160, 160, 16)  1312
# _________________________________________________________________
# activation_13 (Activation)   (None, 30, 160, 160, 16)  0
# _________________________________________________________________
# batch_normalization_19 (Batc (None, 30, 160, 160, 16)  64
# _________________________________________________________________
# max_pooling3d_13 (MaxPooling (None, 15, 80, 80, 16)    0
# _________________________________________________________________
# conv3d_14 (Conv3D)           (None, 15, 80, 80, 32)    4128
# _________________________________________________________________
# activation_14 (Activation)   (None, 15, 80, 80, 32)    0
# _________________________________________________________________
# batch_normalization_20 (Batc (None, 15, 80, 80, 32)    128
# _________________________________________________________________
# max_pooling3d_14 (MaxPooling (None, 7, 40, 40, 32)     0
# _________________________________________________________________
# conv3d_15 (Conv3D)           (None, 7, 40, 40, 64)     16448
# _________________________________________________________________
# activation_15 (Activation)   (None, 7, 40, 40, 64)     0
# _________________________________________________________________
# batch_normalization_21 (Batc (None, 7, 40, 40, 64)     256
# _________________________________________________________________
# max_pooling3d_15 (MaxPooling (None, 3, 20, 20, 64)     0
# _________________________________________________________________
# conv3d_16 (Conv3D)           (None, 3, 20, 20, 128)    65664
# _________________________________________________________________
# activation_16 (Activation)   (None, 3, 20, 20, 128)    0
# _________________________________________________________________
# batch_normalization_22 (Batc (None, 3, 20, 20, 128)    512
# _________________________________________________________________
# max_pooling3d_16 (MaxPooling (None, 1, 10, 10, 128)    0
# _________________________________________________________________
# flatten_4 (Flatten)          (None, 12800)             0
# _________________________________________________________________
# dense_10 (Dense)             (None, 128)               1638528
# _________________________________________________________________
# batch_normalization_23 (Batc (None, 128)               512
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 128)               0
# _________________________________________________________________
# dense_11 (Dense)             (None, 64)                8256
# _________________________________________________________________
# batch_normalization_24 (Batc (None, 64)                256
# _________________________________________________________________
# dropout_8 (Dropout)          (None, 64)                0
# _________________________________________________________________
# dense_12 (Dense)             (None, 5)                 325
# =================================================================
# Total params: 1,736,389
# Trainable params: 1,735,525
# Non-trainable params: 864
# _________________________________________________________________
# Total Params: 1736389
# Epoch 1/30
# /mnt/disks/user/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:55: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imread`` instead.
# /mnt/disks/user/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:56: DeprecationWarning: `imresize` is deprecated!
# `imresize` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``skimage.transform.resize`` instead.
# 23/23 [==============================] - 100s 4s/step - loss: 1.7455 - categorical_accuracy: 0.3856 - val_loss: 2.0531 - val_categorical_accuracy: 0.3700
#
# Epoch 00001: saving model to model_init_2021-02-0807_43_26.250032/model-00001-1.74571-0.38763-2.05307-0.37000.h5
# Epoch 2/30
# 23/23 [==============================] - 86s 4s/step - loss: 1.1665 - categorical_accuracy: 0.5572 - val_loss: 1.7547 - val_categorical_accuracy: 0.5100
#
# Epoch 00002: saving model to model_init_2021-02-0807_43_26.250032/model-00002-1.20559-0.53997-1.75467-0.51000.h5
# Epoch 3/30
# 23/23 [==============================] - 88s 4s/step - loss: 1.0020 - categorical_accuracy: 0.6333 - val_loss: 0.9932 - val_categorical_accuracy: 0.6700
#
# Epoch 00003: saving model to model_init_2021-02-0807_43_26.250032/model-00003-0.97345-0.63198-0.99318-0.67000.h5
# Epoch 4/30
# 23/23 [==============================] - 89s 4s/step - loss: 0.8070 - categorical_accuracy: 0.6899 - val_loss: 0.8746 - val_categorical_accuracy: 0.6700
#
# Epoch 00004: saving model to model_init_2021-02-0807_43_26.250032/model-00004-0.79965-0.69080-0.87457-0.67000.h5
# Epoch 5/30
# 23/23 [==============================] - 87s 4s/step - loss: 0.9002 - categorical_accuracy: 0.6672 - val_loss: 2.0255 - val_categorical_accuracy: 0.4200
#
# Epoch 00005: saving model to model_init_2021-02-0807_43_26.250032/model-00005-0.86841-0.68024-2.02552-0.42000.h5
# Epoch 6/30
# 23/23 [==============================] - 87s 4s/step - loss: 0.9020 - categorical_accuracy: 0.6440 - val_loss: 2.9009 - val_categorical_accuracy: 0.3600
#
# Epoch 00006: saving model to model_init_2021-02-0807_43_26.250032/model-00006-0.85901-0.65611-2.90091-0.36000.h5
# Epoch 7/30
# 23/23 [==============================] - 86s 4s/step - loss: 0.7160 - categorical_accuracy: 0.7355 - val_loss: 1.8241 - val_categorical_accuracy: 0.5100
#
# Epoch 00007: saving model to model_init_2021-02-0807_43_26.250032/model-00007-0.70757-0.75113-1.82414-0.51000.h5
# Epoch 8/30
# 23/23 [==============================] - 85s 4s/step - loss: 0.6980 - categorical_accuracy: 0.7407 - val_loss: 1.5016 - val_categorical_accuracy: 0.4800
#
# Epoch 00008: saving model to model_init_2021-02-0807_43_26.250032/model-00008-0.68305-0.74359-1.50160-0.48000.h5
#
# Epoch 00008: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# Epoch 9/30
# 23/23 [==============================] - 85s 4s/step - loss: 0.5231 - categorical_accuracy: 0.8069 - val_loss: 1.5074 - val_categorical_accuracy: 0.5300
#
# Epoch 00009: saving model to model_init_2021-02-0807_43_26.250032/model-00009-0.53946-0.79940-1.50743-0.53000.h5
# Epoch 10/30
# 23/23 [==============================] - 86s 4s/step - loss: 0.5550 - categorical_accuracy: 0.7660 - val_loss: 1.0416 - val_categorical_accuracy: 0.6300
#
# Epoch 00010: saving model to model_init_2021-02-0807_43_26.250032/model-00010-0.54616-0.78281-1.04163-0.63000.h5
# Epoch 11/30
# 23/23 [==============================] - 86s 4s/step - loss: 0.4877 - categorical_accuracy: 0.8293 - val_loss: 0.8762 - val_categorical_accuracy: 0.6800
#
# Epoch 00011: saving model to model_init_2021-02-0807_43_26.250032/model-00011-0.46720-0.83560-0.87617-0.68000.h5
# Epoch 12/30
# 23/23 [==============================] - 85s 4s/step - loss: 0.4156 - categorical_accuracy: 0.8496 - val_loss: 0.8030 - val_categorical_accuracy: 0.6800
#
# Epoch 00012: saving model to model_init_2021-02-0807_43_26.250032/model-00012-0.40825-0.85671-0.80305-0.68000.h5
# Epoch 13/30
# 23/23 [==============================] - 85s 4s/step - loss: 0.4184 - categorical_accuracy: 0.8409 - val_loss: 0.7805 - val_categorical_accuracy: 0.7200
#
# Epoch 00013: saving model to model_init_2021-02-0807_43_26.250032/model-00013-0.40055-0.84766-0.78051-0.72000.h5
# Epoch 14/30
# 23/23 [==============================] - 84s 4s/step - loss: 0.4088 - categorical_accuracy: 0.8627 - val_loss: 0.7715 - val_categorical_accuracy: 0.7300
#
# Epoch 00014: saving model to model_init_2021-02-0807_43_26.250032/model-00014-0.36859-0.87029-0.77147-0.73000.h5
# Epoch 15/30
# 23/23 [==============================] - 85s 4s/step - loss: 0.4377 - categorical_accuracy: 0.8609 - val_loss: 0.7761 - val_categorical_accuracy: 0.7100
#
# Epoch 00015: saving model to model_init_2021-02-0807_43_26.250032/model-00015-0.34128-0.89442-0.77613-0.71000.h5
# Epoch 16/30
# 23/23 [==============================] - 84s 4s/step - loss: 0.3655 - categorical_accuracy: 0.8690 - val_loss: 0.6509 - val_categorical_accuracy: 0.7600
#
# Epoch 00016: saving model to model_init_2021-02-0807_43_26.250032/model-00016-0.34548-0.88989-0.65095-0.76000.h5
# Epoch 17/30
# 23/23 [==============================] - 84s 4s/step - loss: 0.3571 - categorical_accuracy: 0.8699 - val_loss: 0.5291 - val_categorical_accuracy: 0.8100
#
# Epoch 00017: saving model to model_init_2021-02-0807_43_26.250032/model-00017-0.34031-0.87783-0.52908-0.81000.h5
# Epoch 18/30
# 23/23 [==============================] - 85s 4s/step - loss: 0.3733 - categorical_accuracy: 0.8560 - val_loss: 0.4978 - val_categorical_accuracy: 0.8400
#
# Epoch 00018: saving model to model_init_2021-02-0807_43_26.250032/model-00018-0.34020-0.87632-0.49778-0.84000.h5
# Epoch 19/30
# 23/23 [==============================] - 84s 4s/step - loss: 0.3885 - categorical_accuracy: 0.8859 - val_loss: 0.5396 - val_categorical_accuracy: 0.8200
#
# Epoch 00019: saving model to model_init_2021-02-0807_43_26.250032/model-00019-0.32145-0.89442-0.53959-0.82000.h5
# Epoch 20/30
# 23/23 [==============================] - 84s 4s/step - loss: 0.3071 - categorical_accuracy: 0.9149 - val_loss: 0.5772 - val_categorical_accuracy: 0.7800
#
# Epoch 00020: saving model to model_init_2021-02-0807_43_26.250032/model-00020-0.26207-0.92459-0.57720-0.78000.h5
# Epoch 21/30
# 23/23 [==============================] - 84s 4s/step - loss: 0.2676 - categorical_accuracy: 0.9251 - val_loss: 0.5934 - val_categorical_accuracy: 0.7500
#
# Epoch 00021: saving model to model_init_2021-02-0807_43_26.250032/model-00021-0.24249-0.93514-0.59341-0.75000.h5
# Epoch 22/30
# 23/23 [==============================] - 83s 4s/step - loss: 0.3632 - categorical_accuracy: 0.8864 - val_loss: 0.5956 - val_categorical_accuracy: 0.7900
#
# Epoch 00022: saving model to model_init_2021-02-0807_43_26.250032/model-00022-0.29025-0.90799-0.59558-0.79000.h5
#
# Epoch 00022: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
# Epoch 23/30
# 23/23 [==============================] - 84s 4s/step - loss: 0.3055 - categorical_accuracy: 0.9056 - val_loss: 0.5646 - val_categorical_accuracy: 0.7900
#
# Epoch 00023: saving model to model_init_2021-02-0807_43_26.250032/model-00023-0.30955-0.90196-0.56464-0.79000.h5
# Epoch 24/30
# 23/23 [==============================] - 84s 4s/step - loss: 0.3618 - categorical_accuracy: 0.8902 - val_loss: 0.5221 - val_categorical_accuracy: 0.8300
#
# Epoch 00024: saving model to model_init_2021-02-0807_43_26.250032/model-00024-0.30689-0.89894-0.52212-0.83000.h5
# Epoch 25/30
# 23/23 [==============================] - 84s 4s/step - loss: 0.2457 - categorical_accuracy: 0.9173 - val_loss: 0.4886 - val_categorical_accuracy: 0.8600
#
# Epoch 00025: saving model to model_init_2021-02-0807_43_26.250032/model-00025-0.25410-0.91403-0.48857-0.86000.h5
# Epoch 26/30
# 23/23 [==============================] - 84s 4s/step - loss: 0.3835 - categorical_accuracy: 0.8696 - val_loss: 0.4605 - val_categorical_accuracy: 0.8900
#
# Epoch 00026: saving model to model_init_2021-02-0807_43_26.250032/model-00026-0.28969-0.90347-0.46051-0.89000.h5
# Epoch 27/30
# 23/23 [==============================] - 85s 4s/step - loss: 0.3129 - categorical_accuracy: 0.8937 - val_loss: 0.4306 - val_categorical_accuracy: 0.8800
#
# Epoch 00027: saving model to model_init_2021-02-0807_43_26.250032/model-00027-0.26714-0.91554-0.43064-0.88000.h5
# Epoch 28/30
# 23/23 [==============================] - 86s 4s/step - loss: 0.2309 - categorical_accuracy: 0.9347 - val_loss: 0.4311 - val_categorical_accuracy: 0.8700
#
# Epoch 00028: saving model to model_init_2021-02-0807_43_26.250032/model-00028-0.23418-0.93213-0.43114-0.87000.h5
# Epoch 29/30
# 23/23 [==============================] - 88s 4s/step - loss: 0.3016 - categorical_accuracy: 0.9178 - val_loss: 0.4269 - val_categorical_accuracy: 0.8700
#
# Epoch 00029: saving model to model_init_2021-02-0807_43_26.250032/model-00029-0.23156-0.92760-0.42689-0.87000.h5
# Epoch 30/30
# 23/23 [==============================] - 88s 4s/step - loss: 0.2407 - categorical_accuracy: 0.9274 - val_loss: 0.4486 - val_categorical_accuracy: 0.8700
#
# Epoch 00030: saving model to model_init_2021-02-0807_43_26.250032/model-00030-0.23919-0.92459-0.44856-0.87000.h5

# %% [markdown]
# ### Conclusion : The accuracy increased to 93/87 % with number of epochs but execution time also increases.

# %% [markdown]
# ### Model 5 - New Architecture with Reduced Parameters

# %%
class ModelConv3D5(ModelBuilder):
    
    def define_model(self,dense_neurons=32,dropout=0.25):

        model = Sequential()
        model.add(Conv3D(16, (3, 3, 3), padding='same',
                 input_shape=(self.frames_to_sample,self.image_height,self.image_width,self.channels)))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        model.add(MaxPooling3D(pool_size=(2, 2, 2)))

        model.add(Conv3D(32, (2, 2, 2), padding='same'))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        model.add(MaxPooling3D(pool_size=(2, 2, 2)))

        model.add(Conv3D(64, (2, 2, 2), padding='same'))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        model.add(MaxPooling3D(pool_size=(2, 2, 2)))

        model.add(Conv3D(128, (2, 2, 2), padding='same'))
        model.add(Activation('relu'))
        model.add(BatchNormalization())
        model.add(MaxPooling3D(pool_size=(2, 2, 2)))
        
        model.add(Flatten())
        model.add(Dense(dense_neurons,activation='relu'))
        model.add(BatchNormalization())
        model.add(Dropout(dropout))

        model.add(Dense(dense_neurons,activation='relu'))
        model.add(BatchNormalization())
        model.add(Dropout(dropout))

        model.add(Dense(self.num_classes,activation='softmax'))

        optimiser = optimizers.Adam(lr=0.0002)
        model.compile(optimizer=optimiser, loss='categorical_crossentropy', metrics=['categorical_accuracy'])
        return model

# %%
conv_3d5=ModelConv3D5()
conv_3d5.initialize_path(project_folder)
conv_3d5.initialize_image_properties(image_height=160,image_width=160)
conv_3d5.initialize_hyperparams(frames_to_sample=30,batch_size=30,num_epochs=10)
conv_3d5_model=conv_3d5.define_model()
conv_3d5_model.summary()
print("Total Params:", conv_3d5_model.count_params())
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv3d_21 (Conv3D)           (None, 30, 160, 160, 16)  1312
# _________________________________________________________________
# activation_21 (Activation)   (None, 30, 160, 160, 16)  0
# _________________________________________________________________
# batch_normalization_31 (Batc (None, 30, 160, 160, 16)  64
# _________________________________________________________________
# max_pooling3d_21 (MaxPooling (None, 15, 80, 80, 16)    0
# _________________________________________________________________
# conv3d_22 (Conv3D)           (None, 15, 80, 80, 32)    4128
# _________________________________________________________________
# activation_22 (Activation)   (None, 15, 80, 80, 32)    0
# _________________________________________________________________
# batch_normalization_32 (Batc (None, 15, 80, 80, 32)    128
# _________________________________________________________________
# max_pooling3d_22 (MaxPooling (None, 7, 40, 40, 32)     0
# _________________________________________________________________
# conv3d_23 (Conv3D)           (None, 7, 40, 40, 64)     16448
# _________________________________________________________________
# activation_23 (Activation)   (None, 7, 40, 40, 64)     0
# _________________________________________________________________
# batch_normalization_33 (Batc (None, 7, 40, 40, 64)     256
# _________________________________________________________________
# max_pooling3d_23 (MaxPooling (None, 3, 20, 20, 64)     0
# _________________________________________________________________
# conv3d_24 (Conv3D)           (None, 3, 20, 20, 128)    65664
# _________________________________________________________________
# activation_24 (Activation)   (None, 3, 20, 20, 128)    0
# _________________________________________________________________
# batch_normalization_34 (Batc (None, 3, 20, 20, 128)    512
# _________________________________________________________________
# max_pooling3d_24 (MaxPooling (None, 1, 10, 10, 128)    0
# _________________________________________________________________
# flatten_6 (Flatten)          (None, 12800)             0
# _________________________________________________________________
# dense_16 (Dense)             (None, 32)                409632
# _________________________________________________________________
# batch_normalization_35 (Batc (None, 32)                128
# _________________________________________________________________
# dropout_11 (Dropout)         (None, 32)                0
# _________________________________________________________________
# dense_17 (Dense)             (None, 32)                1056
# _________________________________________________________________
# batch_normalization_36 (Batc (None, 32)                128
# _________________________________________________________________
# dropout_12 (Dropout)         (None, 32)                0
# _________________________________________________________________
# dense_18 (Dense)             (None, 5)                 165
# =================================================================
# Total params: 499,621
# Trainable params: 499,013
# Non-trainable params: 608
# _________________________________________________________________
# Total Params: 499621

# %%
history_model5 = conv_3d5.train_model(conv_3d5_model)
# Out:
# Epoch 1/10
# /mnt/disks/user/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:55: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imread`` instead.
# /mnt/disks/user/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:56: DeprecationWarning: `imresize` is deprecated!
# `imresize` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``skimage.transform.resize`` instead.
# 23/23 [==============================] - 100s 4s/step - loss: 1.8192 - categorical_accuracy: 0.3290 - val_loss: 1.3000 - val_categorical_accuracy: 0.4600
#
# Epoch 00001: saving model to model_init_2021-02-0808_45_11.011168/model-00001-1.79243-0.32881-1.29996-0.46000.h5
# Epoch 2/10
# 23/23 [==============================] - 84s 4s/step - loss: 1.3224 - categorical_accuracy: 0.4901 - val_loss: 1.4540 - val_categorical_accuracy: 0.4700
#
# Epoch 00002: saving model to model_init_2021-02-0808_45_11.011168/model-00002-1.28538-0.49623-1.45398-0.47000.h5
# Epoch 3/10
# 23/23 [==============================] - 86s 4s/step - loss: 1.1805 - categorical_accuracy: 0.5476 - val_loss: 1.4244 - val_categorical_accuracy: 0.4400
#
# Epoch 00003: saving model to model_init_2021-02-0808_45_11.011168/model-00003-1.19138-0.54299-1.42437-0.44000.h5
# Epoch 4/10
# 23/23 [==============================] - 86s 4s/step - loss: 0.9798 - categorical_accuracy: 0.6376 - val_loss: 1.2101 - val_categorical_accuracy: 0.5400
#
# Epoch 00004: saving model to model_init_2021-02-0808_45_11.011168/model-00004-0.95328-0.63650-1.21010-0.54000.h5
# Epoch 5/10
# 23/23 [==============================] - 87s 4s/step - loss: 0.8791 - categorical_accuracy: 0.6632 - val_loss: 1.0853 - val_categorical_accuracy: 0.6100
#
# Epoch 00005: saving model to model_init_2021-02-0808_45_11.011168/model-00005-0.90395-0.65008-1.08535-0.61000.h5
# Epoch 6/10
# 23/23 [==============================] - 85s 4s/step - loss: 0.7477 - categorical_accuracy: 0.7184 - val_loss: 0.9071 - val_categorical_accuracy: 0.6900
#
# Epoch 00006: saving model to model_init_2021-02-0808_45_11.011168/model-00006-0.77030-0.70739-0.90709-0.69000.h5
# Epoch 7/10
# 23/23 [==============================] - 85s 4s/step - loss: 0.6645 - categorical_accuracy: 0.7697 - val_loss: 0.9571 - val_categorical_accuracy: 0.6600
#
# Epoch 00007: saving model to model_init_2021-02-0808_45_11.011168/model-00007-0.66072-0.77376-0.95712-0.66000.h5
# Epoch 8/10
# 23/23 [==============================] - 85s 4s/step - loss: 0.6678 - categorical_accuracy: 0.7697 - val_loss: 1.1385 - val_categorical_accuracy: 0.5700
#
# Epoch 00008: saving model to model_init_2021-02-0808_45_11.011168/model-00008-0.65722-0.77376-1.13855-0.57000.h5
# Epoch 9/10
# 23/23 [==============================] - 86s 4s/step - loss: 0.6712 - categorical_accuracy: 0.7451 - val_loss: 0.9319 - val_categorical_accuracy: 0.6400
#
# Epoch 00009: saving model to model_init_2021-02-0808_45_11.011168/model-00009-0.66410-0.74811-0.93189-0.64000.h5
# Epoch 10/10
# 23/23 [==============================] - 87s 4s/step - loss: 0.7131 - categorical_accuracy: 0.7505 - val_loss: 0.9348 - val_categorical_accuracy: 0.6400
#
# Epoch 00010: saving model to model_init_2021-02-0808_45_11.011168/model-00010-0.63127-0.77979-0.93478-0.64000.h5
#
# Epoch 00010: ReduceLROnPlateau reducing learning rate to 3.9999998989515007e-05.

# %% [markdown]
# ### Conclusion : Reducing the number of Parameters has increased accuracy significantly .
# Accuracy with 10 Epochs with model having more parameters is far less than that with model having less parameters.

# %% [markdown]
# ### Model 6 : Increase the Epochs to 30 in the model with reduced parameters.

# %%
### Model 6 - Same Architecture as previous with  increase in Epochs.

conv_3d6=ModelConv3D5()
conv_3d6.initialize_path(project_folder)
conv_3d6.initialize_image_properties(image_height=160,image_width=160)
conv_3d6.initialize_hyperparams(frames_to_sample=30,batch_size=30,num_epochs=30)
conv_3d6_model=conv_3d6.define_model()
conv_3d6_model.summary()
print("Total Params:", conv_3d6_model.count_params())
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv3d_29 (Conv3D)           (None, 30, 160, 160, 16)  1312
# _________________________________________________________________
# activation_29 (Activation)   (None, 30, 160, 160, 16)  0
# _________________________________________________________________
# batch_normalization_43 (Batc (None, 30, 160, 160, 16)  64
# _________________________________________________________________
# max_pooling3d_29 (MaxPooling (None, 15, 80, 80, 16)    0
# _________________________________________________________________
# conv3d_30 (Conv3D)           (None, 15, 80, 80, 32)    4128
# _________________________________________________________________
# activation_30 (Activation)   (None, 15, 80, 80, 32)    0
# _________________________________________________________________
# batch_normalization_44 (Batc (None, 15, 80, 80, 32)    128
# _________________________________________________________________
# max_pooling3d_30 (MaxPooling (None, 7, 40, 40, 32)     0
# _________________________________________________________________
# conv3d_31 (Conv3D)           (None, 7, 40, 40, 64)     16448
# _________________________________________________________________
# activation_31 (Activation)   (None, 7, 40, 40, 64)     0
# _________________________________________________________________
# batch_normalization_45 (Batc (None, 7, 40, 40, 64)     256
# _________________________________________________________________
# max_pooling3d_31 (MaxPooling (None, 3, 20, 20, 64)     0
# _________________________________________________________________
# conv3d_32 (Conv3D)           (None, 3, 20, 20, 128)    65664
# _________________________________________________________________
# activation_32 (Activation)   (None, 3, 20, 20, 128)    0
# _________________________________________________________________
# batch_normalization_46 (Batc (None, 3, 20, 20, 128)    512
# _________________________________________________________________
# max_pooling3d_32 (MaxPooling (None, 1, 10, 10, 128)    0
# _________________________________________________________________
# flatten_8 (Flatten)          (None, 12800)             0
# _________________________________________________________________
# dense_22 (Dense)             (None, 32)                409632
# _________________________________________________________________
# batch_normalization_47 (Batc (None, 32)                128
# _________________________________________________________________
# dropout_15 (Dropout)         (None, 32)                0
# _________________________________________________________________
# dense_23 (Dense)             (None, 32)                1056
# _________________________________________________________________
# batch_normalization_48 (Batc (None, 32)                128
# _________________________________________________________________
# dropout_16 (Dropout)         (None, 32)                0
# _________________________________________________________________
# dense_24 (Dense)             (None, 5)                 165
# =================================================================
# Total params: 499,621
# Trainable params: 499,013
# Non-trainable params: 608
# _________________________________________________________________
# Total Params: 499621

# %%
history_model6 = conv_3d6.train_model(conv_3d6_model)
# Out:
# Epoch 1/30
# /mnt/disks/user/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:55: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imread`` instead.
# /mnt/disks/user/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:56: DeprecationWarning: `imresize` is deprecated!
# `imresize` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``skimage.transform.resize`` instead.
# 23/23 [==============================] - 100s 4s/step - loss: 1.8362 - categorical_accuracy: 0.3101 - val_loss: 1.7054 - val_categorical_accuracy: 0.3900
#
# Epoch 00001: saving model to model_init_2021-02-0811_18_15.817203/model-00001-1.84071-0.30920-1.70541-0.39000.h5
# Epoch 2/30
# 23/23 [==============================] - 84s 4s/step - loss: 1.2275 - categorical_accuracy: 0.5157 - val_loss: 1.2813 - val_categorical_accuracy: 0.4400
#
# Epoch 00002: saving model to model_init_2021-02-0811_18_15.817203/model-00002-1.23580-0.50980-1.28127-0.44000.h5
# Epoch 3/30
# 23/23 [==============================] - 88s 4s/step - loss: 1.0214 - categorical_accuracy: 0.5917 - val_loss: 1.1176 - val_categorical_accuracy: 0.6100
#
# Epoch 00003: saving model to model_init_2021-02-0811_18_15.817203/model-00003-0.97327-0.60181-1.11760-0.61000.h5
# Epoch 4/30
# 23/23 [==============================] - 88s 4s/step - loss: 0.9497 - categorical_accuracy: 0.6391 - val_loss: 1.2240 - val_categorical_accuracy: 0.5200
#
# Epoch 00004: saving model to model_init_2021-02-0811_18_15.817203/model-00004-0.95374-0.63801-1.22399-0.52000.h5
# Epoch 5/30
# 23/23 [==============================] - 88s 4s/step - loss: 0.9128 - categorical_accuracy: 0.6527 - val_loss: 1.0192 - val_categorical_accuracy: 0.6100
#
# Epoch 00005: saving model to model_init_2021-02-0811_18_15.817203/model-00005-0.87611-0.66516-1.01920-0.61000.h5
# Epoch 6/30
# 23/23 [==============================] - 87s 4s/step - loss: 0.8183 - categorical_accuracy: 0.7175 - val_loss: 1.2071 - val_categorical_accuracy: 0.5100
#
# Epoch 00006: saving model to model_init_2021-02-0811_18_15.817203/model-00006-0.82585-0.71946-1.20707-0.51000.h5
# Epoch 7/30
# 23/23 [==============================] - 87s 4s/step - loss: 0.7712 - categorical_accuracy: 0.7363 - val_loss: 0.9437 - val_categorical_accuracy: 0.6200
#
# Epoch 00007: saving model to model_init_2021-02-0811_18_15.817203/model-00007-0.73269-0.73906-0.94369-0.62000.h5
# Epoch 8/30
# 23/23 [==============================] - 87s 4s/step - loss: 0.6245 - categorical_accuracy: 0.7968 - val_loss: 0.9017 - val_categorical_accuracy: 0.6400
#
# Epoch 00008: saving model to model_init_2021-02-0811_18_15.817203/model-00008-0.62752-0.78884-0.90174-0.64000.h5
# Epoch 9/30
# 23/23 [==============================] - 87s 4s/step - loss: 0.6345 - categorical_accuracy: 0.7950 - val_loss: 0.9313 - val_categorical_accuracy: 0.6300
#
# Epoch 00009: saving model to model_init_2021-02-0811_18_15.817203/model-00009-0.60829-0.81297-0.93134-0.63000.h5
# Epoch 10/30
# 23/23 [==============================] - 86s 4s/step - loss: 0.5694 - categorical_accuracy: 0.8322 - val_loss: 0.8767 - val_categorical_accuracy: 0.6800
#
# Epoch 00010: saving model to model_init_2021-02-0811_18_15.817203/model-00010-0.55791-0.83861-0.87674-0.68000.h5
# Epoch 11/30
# 23/23 [==============================] - 87s 4s/step - loss: 0.5551 - categorical_accuracy: 0.8264 - val_loss: 0.9812 - val_categorical_accuracy: 0.6800
#
# Epoch 00011: saving model to model_init_2021-02-0811_18_15.817203/model-00011-0.54762-0.83258-0.98125-0.68000.h5
# Epoch 12/30
# 23/23 [==============================] - 86s 4s/step - loss: 0.5339 - categorical_accuracy: 0.8226 - val_loss: 0.9394 - val_categorical_accuracy: 0.6700
#
# Epoch 00012: saving model to model_init_2021-02-0811_18_15.817203/model-00012-0.51900-0.84163-0.93943-0.67000.h5
# Epoch 13/30
# 23/23 [==============================] - 86s 4s/step - loss: 0.4396 - categorical_accuracy: 0.8693 - val_loss: 0.7764 - val_categorical_accuracy: 0.7200
#
# Epoch 00013: saving model to model_init_2021-02-0811_18_15.817203/model-00013-0.44022-0.86425-0.77645-0.72000.h5
# Epoch 14/30
# 23/23 [==============================] - 86s 4s/step - loss: 0.3811 - categorical_accuracy: 0.8931 - val_loss: 0.7935 - val_categorical_accuracy: 0.7500
#
# Epoch 00014: saving model to model_init_2021-02-0811_18_15.817203/model-00014-0.37791-0.90196-0.79351-0.75000.h5
# Epoch 15/30
# 23/23 [==============================] - 86s 4s/step - loss: 0.4093 - categorical_accuracy: 0.8989 - val_loss: 0.7913 - val_categorical_accuracy: 0.7500
#
# Epoch 00015: saving model to model_init_2021-02-0811_18_15.817203/model-00015-0.39695-0.90799-0.79126-0.75000.h5
# Epoch 16/30
# 23/23 [==============================] - 87s 4s/step - loss: 0.3511 - categorical_accuracy: 0.9143 - val_loss: 0.7389 - val_categorical_accuracy: 0.7700
#
# Epoch 00016: saving model to model_init_2021-02-0811_18_15.817203/model-00016-0.35582-0.91101-0.73890-0.77000.h5
# Epoch 17/30
# 23/23 [==============================] - 87s 4s/step - loss: 0.3671 - categorical_accuracy: 0.9164 - val_loss: 0.7513 - val_categorical_accuracy: 0.7500
#
# Epoch 00017: saving model to model_init_2021-02-0811_18_15.817203/model-00017-0.32644-0.92609-0.75127-0.75000.h5
# Epoch 18/30
# 23/23 [==============================] - 87s 4s/step - loss: 0.3480 - categorical_accuracy: 0.9158 - val_loss: 0.7222 - val_categorical_accuracy: 0.7600
#
# Epoch 00018: saving model to model_init_2021-02-0811_18_15.817203/model-00018-0.35082-0.91252-0.72218-0.76000.h5
# Epoch 19/30
# 23/23 [==============================] - 87s 4s/step - loss: 0.3570 - categorical_accuracy: 0.9077 - val_loss: 0.7680 - val_categorical_accuracy: 0.7200
#
# Epoch 00019: saving model to model_init_2021-02-0811_18_15.817203/model-00019-0.32808-0.91704-0.76805-0.72000.h5
# Epoch 20/30
# 23/23 [==============================] - 89s 4s/step - loss: 0.3087 - categorical_accuracy: 0.9193 - val_loss: 0.7879 - val_categorical_accuracy: 0.7000
#
# Epoch 00020: saving model to model_init_2021-02-0811_18_15.817203/model-00020-0.29776-0.92911-0.78787-0.70000.h5
# Epoch 21/30
# 23/23 [==============================] - 88s 4s/step - loss: 0.2785 - categorical_accuracy: 0.9381 - val_loss: 0.7654 - val_categorical_accuracy: 0.7100
#
# Epoch 00021: saving model to model_init_2021-02-0811_18_15.817203/model-00021-0.27727-0.94872-0.76539-0.71000.h5
# Epoch 22/30
# 23/23 [==============================] - 89s 4s/step - loss: 0.2704 - categorical_accuracy: 0.9434 - val_loss: 0.7792 - val_categorical_accuracy: 0.7200
#
# Epoch 00022: saving model to model_init_2021-02-0811_18_15.817203/model-00022-0.25420-0.94118-0.77916-0.72000.h5
#
# Epoch 00022: ReduceLROnPlateau reducing learning rate to 3.9999998989515007e-05.
# Epoch 23/30
# 23/23 [==============================] - 88s 4s/step - loss: 0.3260 - categorical_accuracy: 0.9329 - val_loss: 0.7653 - val_categorical_accuracy: 0.7200
#
# Epoch 00023: saving model to model_init_2021-02-0811_18_15.817203/model-00023-0.25835-0.95626-0.76533-0.72000.h5
# Epoch 24/30
# 23/23 [==============================] - 88s 4s/step - loss: 0.2414 - categorical_accuracy: 0.9623 - val_loss: 0.7390 - val_categorical_accuracy: 0.7500
#
# Epoch 00024: saving model to model_init_2021-02-0811_18_15.817203/model-00024-0.23548-0.96078-0.73904-0.75000.h5
# Epoch 25/30
# 23/23 [==============================] - 88s 4s/step - loss: 0.2345 - categorical_accuracy: 0.9623 - val_loss: 0.7222 - val_categorical_accuracy: 0.7700
#
# Epoch 00025: saving model to model_init_2021-02-0811_18_15.817203/model-00025-0.23882-0.96078-0.72223-0.77000.h5
# Epoch 26/30
# 23/23 [==============================] - 87s 4s/step - loss: 0.2544 - categorical_accuracy: 0.9570 - val_loss: 0.7059 - val_categorical_accuracy: 0.7900
#
# Epoch 00026: saving model to model_init_2021-02-0811_18_15.817203/model-00026-0.21965-0.96833-0.70590-0.79000.h5
# Epoch 27/30
# 23/23 [==============================] - 87s 4s/step - loss: 0.2626 - categorical_accuracy: 0.9381 - val_loss: 0.7020 - val_categorical_accuracy: 0.7900
#
# Epoch 00027: saving model to model_init_2021-02-0811_18_15.817203/model-00027-0.25004-0.94872-0.70197-0.79000.h5
# Epoch 28/30
# 23/23 [==============================] - 87s 4s/step - loss: 0.2180 - categorical_accuracy: 0.9652 - val_loss: 0.7086 - val_categorical_accuracy: 0.7600
#
# Epoch 00028: saving model to model_init_2021-02-0811_18_15.817203/model-00028-0.21397-0.96380-0.70864-0.76000.h5
# Epoch 29/30
# 23/23 [==============================] - 88s 4s/step - loss: 0.2361 - categorical_accuracy: 0.9506 - val_loss: 0.7149 - val_categorical_accuracy: 0.7400
#
# Epoch 00029: saving model to model_init_2021-02-0811_18_15.817203/model-00029-0.24176-0.94872-0.71488-0.74000.h5
# Epoch 30/30
# 23/23 [==============================] - 88s 4s/step - loss: 0.2025 - categorical_accuracy: 0.9739 - val_loss: 0.7122 - val_categorical_accuracy: 0.7300
#
# Epoch 00030: saving model to model_init_2021-02-0811_18_15.817203/model-00030-0.20242-0.97285-0.71224-0.73000.h5

# %% [markdown]
# ### Conclusion : Model seems to overfit. Training Acuracy is in 90s but Validation Accuracy is in 70s.

# %% [markdown]
# ### Model 7 :with augmentation
# Frames : 20, Batch Size : 20, Number of Epochs : 10

# %%
conv_3d7=ModelConv3D5()
conv_3d7.initialize_path(project_folder)
conv_3d7.initialize_image_properties(image_height=160,image_width=160)
conv_3d7.initialize_hyperparams(frames_to_sample=20,batch_size=20,num_epochs=10)
conv_3d7_model=conv_3d7.define_model()

conv_3d7_model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv3d_5 (Conv3D)            (None, 20, 160, 160, 16)  1312
# _________________________________________________________________
# activation_5 (Activation)    (None, 20, 160, 160, 16)  0
# _________________________________________________________________
# batch_normalization_7 (Batch (None, 20, 160, 160, 16)  64
# _________________________________________________________________
# max_pooling3d_5 (MaxPooling3 (None, 10, 80, 80, 16)    0
# _________________________________________________________________
# conv3d_6 (Conv3D)            (None, 10, 80, 80, 32)    4128
# _________________________________________________________________
# activation_6 (Activation)    (None, 10, 80, 80, 32)    0
# _________________________________________________________________
# batch_normalization_8 (Batch (None, 10, 80, 80, 32)    128
# _________________________________________________________________
# max_pooling3d_6 (MaxPooling3 (None, 5, 40, 40, 32)     0
# _________________________________________________________________
# conv3d_7 (Conv3D)            (None, 5, 40, 40, 64)     16448
# _________________________________________________________________
# activation_7 (Activation)    (None, 5, 40, 40, 64)     0
# _________________________________________________________________
# batch_normalization_9 (Batch (None, 5, 40, 40, 64)     256
# _________________________________________________________________
# max_pooling3d_7 (MaxPooling3 (None, 2, 20, 20, 64)     0
# _________________________________________________________________
# conv3d_8 (Conv3D)            (None, 2, 20, 20, 128)    65664
# _________________________________________________________________
# activation_8 (Activation)    (None, 2, 20, 20, 128)    0
# _________________________________________________________________
# batch_normalization_10 (Batc (None, 2, 20, 20, 128)    512
# _________________________________________________________________
# max_pooling3d_8 (MaxPooling3 (None, 1, 10, 10, 128)    0
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 12800)             0
# _________________________________________________________________
# dense_4 (Dense)              (None, 32)                409632
# _________________________________________________________________
# batch_normalization_11 (Batc (None, 32)                128
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 32)                0
# _________________________________________________________________
# dense_5 (Dense)              (None, 32)                1056
# _________________________________________________________________
# batch_normalization_12 (Batc (None, 32)                128
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 32)                0
# _________________________________________________________________
# dense_6 (Dense)              (None, 5)                 165
# =================================================================
# Total params: 499,621
# Trainable params: 499,013
# Non-trainable params: 608
# _________________________________________________________________

# %%
print("Total Params:", conv_3d7_model.count_params())
history_model7=conv_3d7.train_model(conv_3d7_model,augment_data=True)
# Out:
# Total Params: 499621
# Epoch 1/10
# /mnt/disks/user/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:55: DeprecationWarning: `imread` is deprecated!
# `imread` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``imageio.imread`` instead.
# /mnt/disks/user/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:56: DeprecationWarning: `imresize` is deprecated!
# `imresize` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``skimage.transform.resize`` instead.
# /mnt/disks/user/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:75: DeprecationWarning: `imresize` is deprecated!
# `imresize` is deprecated in SciPy 1.0.0, and will be removed in 1.2.0.
# Use ``skimage.transform.resize`` instead.
# 34/34 [==============================] - 235s 7s/step - loss: 1.7735 - categorical_accuracy: 0.3072 - val_loss: 1.1699 - val_categorical_accuracy: 0.5300
#
# Epoch 00001: saving model to model_init_2021-02-0812_52_41.145224/model-00001-1.76265-0.31071-1.16986-0.53000.h5
# Epoch 2/10
# 34/34 [==============================] - 128s 4s/step - loss: 1.2838 - categorical_accuracy: 0.4882 - val_loss: 1.1999 - val_categorical_accuracy: 0.5600
#
# Epoch 00002: saving model to model_init_2021-02-0812_52_41.145224/model-00002-1.28640-0.48793-1.19994-0.56000.h5
# Epoch 3/10
# 34/34 [==============================] - 130s 4s/step - loss: 1.1034 - categorical_accuracy: 0.5784 - val_loss: 1.2040 - val_categorical_accuracy: 0.5200
#
# Epoch 00003: saving model to model_init_2021-02-0812_52_41.145224/model-00003-1.09692-0.57617-1.20404-0.52000.h5
# Epoch 4/10
# 34/34 [==============================] - 129s 4s/step - loss: 1.0612 - categorical_accuracy: 0.5754 - val_loss: 0.9630 - val_categorical_accuracy: 0.6800
#
# Epoch 00004: saving model to model_init_2021-02-0812_52_41.145224/model-00004-1.04155-0.58145-0.96305-0.68000.h5
# Epoch 5/10
# 34/34 [==============================] - 129s 4s/step - loss: 0.9383 - categorical_accuracy: 0.6365 - val_loss: 0.9927 - val_categorical_accuracy: 0.6400
#
# Epoch 00005: saving model to model_init_2021-02-0812_52_41.145224/model-00005-0.93589-0.64404-0.99273-0.64000.h5
# Epoch 6/10
# 34/34 [==============================] - 130s 4s/step - loss: 0.8404 - categorical_accuracy: 0.6902 - val_loss: 0.8974 - val_categorical_accuracy: 0.6800
#
# Epoch 00006: saving model to model_init_2021-02-0812_52_41.145224/model-00006-0.84449-0.68250-0.89735-0.68000.h5
# Epoch 7/10
# 34/34 [==============================] - 131s 4s/step - loss: 0.8148 - categorical_accuracy: 0.7001 - val_loss: 0.9410 - val_categorical_accuracy: 0.6700
#
# Epoch 00007: saving model to model_init_2021-02-0812_52_41.145224/model-00007-0.78660-0.71342-0.94099-0.67000.h5
# Epoch 8/10
# 34/34 [==============================] - 128s 4s/step - loss: 0.7099 - categorical_accuracy: 0.7535 - val_loss: 0.8689 - val_categorical_accuracy: 0.6700
#
# Epoch 00008: saving model to model_init_2021-02-0812_52_41.145224/model-00008-0.71580-0.75566-0.86892-0.67000.h5
# Epoch 9/10
# 34/34 [==============================] - 125s 4s/step - loss: 0.6806 - categorical_accuracy: 0.7598 - val_loss: 0.8881 - val_categorical_accuracy: 0.7000
#
# Epoch 00009: saving model to model_init_2021-02-0812_52_41.145224/model-00009-0.67986-0.75792-0.88806-0.70000.h5
# Epoch 10/10
# 34/34 [==============================] - 125s 4s/step - loss: 0.6965 - categorical_accuracy: 0.7616 - val_loss: 0.9312 - val_categorical_accuracy: 0.6200
#
# Epoch 00010: saving model to model_init_2021-02-0812_52_41.145224/model-00010-0.67851-0.76395-0.93118-0.62000.h5

# %% [markdown]
# ### Accuracy has not improved with Augmentation.
